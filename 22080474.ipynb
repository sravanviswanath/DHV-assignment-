# %% [markdown]
# # Importing Iibraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
data = pd.read_csv('world_nuclear_power_dataset.csv')

# %% [markdown]
# # Display the first few rows of the dataset

# %%
print(data.head())
# Out:
#       Country                   Power_Plant  Capacity_MW  Year_Commissioned  \
# 0   Indonesia          Novak, Wood and Snow       132200               2002
# 1       Japan                    Campos Inc       212200               1976
# 2  Montserrat   Patterson, Stokes and Adams       293200               2011
# 3      Guinea  Parks, Lambert and Mcfarland       120800               2007
# 4      Canada      Salazar, Rowe and Powell       354200               1994
#
#                          Operator                       Type  \
# 0                   Perez-Schmidt       Fast Breeder Reactor
# 1     Carroll, Petersen and Smith      Boiling Water Reactor
# 2      Arnold, Perkins and Holmes       Fast Breeder Reactor
# 3  Bradshaw, Mcdonald and Ballard  Pressurized Water Reactor
# 4                     Ellis-Ayala       Fast Breeder Reactor
#
#                Fuel                 Location       Status  Construction_Start  \
# 0           Thorium   North Scott, Indonesia  Operational                1971
# 1           Thorium    Matthewborough, Japan  Operational                2020
# 2  Mixed Oxide Fuel  Ashleymouth, Montserrat  Operational                2009
# 3  Mixed Oxide Fuel       Howardstad, Guinea  Operational                1982
# 4  Mixed Oxide Fuel   Mullinschester, Canada      Planned                2011
#
#    Cost_Billion_USD  Safety_Rating
# 0              1.87              2
# 1              1.91              3
# 2              2.78              3
# 3              4.86              5
# 4              6.17              3

# %% [markdown]
# # Summary statistics

# %%
print(data.describe())
# Out:
#          Capacity_MW  Year_Commissioned  Construction_Start  Cost_Billion_USD  \
# count    1200.000000        1200.000000         1200.000000       1200.000000
# mean   271797.000000        1996.595000         1997.383333          5.486267
# std    130901.428096          15.375022           15.669908          2.634550
# min     50000.000000        1970.000000         1970.000000          1.030000
# 25%    156225.000000        1983.000000         1984.000000          3.190000
# 50%    267200.000000        1997.000000         1997.000000          5.480000
# 75%    383425.000000        2009.250000         2011.000000          7.802500
# max    500000.000000        2023.000000         2023.000000         10.000000
#
#        Safety_Rating
# count    1200.000000
# mean        3.059167
# std         1.403795
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %% [markdown]
# # Check for missing values

# %%
print(data.isnull().sum())
# Out:
# Country               0
# Power_Plant           0
# Capacity_MW           0
# Year_Commissioned     0
# Operator              0
# Type                  0
# Fuel                  0
# Location              0
# Status                0
# Construction_Start    0
# Cost_Billion_USD      0
# Safety_Rating         0
# dtype: int64

# %% [markdown]
# # Check data types

# %%
print(data.dtypes)
# Out:
# Country                object
# Power_Plant            object
# Capacity_MW             int64
# Year_Commissioned       int64
# Operator               object
# Type                   object
# Fuel                   object
# Location               object
# Status                 object
# Construction_Start      int64
# Cost_Billion_USD      float64
# Safety_Rating           int64
# dtype: object

# %% [markdown]
# # Visualization 1: Distribution of Power Plant Capacity

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Capacity_MW'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Power Plant Capacity')
plt.xlabel('Capacity (MW)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Visualization 2: Power Plant Status Count

# %%
plt.figure(figsize=(8, 6))
status_count = data['Status'].value_counts()
sns.barplot(x=status_count.index, y=status_count.values, palette='viridis')
plt.title('Power Plant Status')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # DASHBOARD-WORLD NUCLEAR POWER

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assume 'data' contains the dataset for visualization

# Create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.patch.set_facecolor('lightgrey')  # Set background color

# Visualization 1: Bar plot
sns.countplot(x='Status', data=data, ax=axs[0, 0], palette='muted')
axs[0, 0].set_title('Power Plant Status')

# Visualization 2: Pie plot with color strip legend
status_counts = data['Status'].value_counts()
axs[0, 1].pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('muted'))
axs[0, 1].legend(bbox_to_anchor=(1, 1), loc='upper left', labels=status_counts.index)
axs[0, 1].set_title('Status Distribution')

# Visualization 3: Histogram plot
sns.histplot(data['Capacity_MW'], bins=20, kde=True, ax=axs[1, 0], color='skyblue')
axs[1, 0].set_title('Distribution of Power Plant Capacity')
axs[1, 0].set_xlabel('Capacity (MW)')
axs[1, 0].set_ylabel('Frequency')

# Visualization 4: Line plot (example using random data)
years = np.arange(2000, 2020)
random_values = np.random.randint(100, 1000, size=len(years))
axs[1, 1].plot(years, random_values, marker='o', linestyle='-', color='green')
axs[1, 1].set_title('Random Line Plot')
axs[1, 1].set_xlabel('Year')
axs[1, 1].set_ylabel('Random Values')

# Adjust layout
plt.tight_layout()

# Save the dashboard as an image
plt.savefig('2324VS0013_sravan.png', dpi=300)  

# Description
description = "It explores power plant status distribution, capacity range, and a random trend over years. Utilizing varied plot types, it provides insights into the dataset's status, capacity distribution, and a temporal trend without specifically mentioning individual plot details. The visualizations offer a comprehensive overview of the power plant data's key aspects, aiding in quick insights and analysis."

# Add description
fig_desc = plt.figure(figsize=(12, 3))
plt.text(0, 0, description + "\n\nName: Vinnakota Sravan Viswanath\n"\
         "Student ID: 22080474", 
         ha='left', va='center', fontsize=14, wrap=True)
plt.axis('off')

# Save description with the dashboard image
plt.savefig('2324VS0013_sravan_with_desc.png', dpi=300)
